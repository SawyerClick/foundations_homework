# %% [markdown]
# # Metrolyrics (Pagination, scraping 1x per row)
# Link : http://www.metrolyrics.com/rage-against-the-machine-lyrics.html

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
# http://www.metrolyrics.com/rage-against-the-machine-alpage-1.html

# %%
rows = []

for page_num in range(1,4):
    url = "http://www.metrolyrics.com/nirvana-alpage-" + str(page_num)
    
    response = requests.get(url)
    doc = BeautifulSoup(response.text)

    songs = doc.find("tbody").find_all('tr')
    for song in songs:
        row = {}

        row['title'] = song.find_all('td')[1].find('a').text.strip()
        row['slug'] = song.find_all('td')[1].find('a')['href']
        row['year'] = song.find_all('td')[2].text.strip()
        row['popularity'] = song.find_all('span')[1].get('style')

        rows.append(row)
        
print(rows)
# Out:
# [{'title': '(new Wave) Polly [mark Goodier Session] Lyrics', 'slug': 'http://www.metrolyrics.com/new-wave-polly-mark-goodier-session-lyrics-nirvana.html', 'year': '2006', 'popularity': 'width:6%;'}, {'title': '02 Lyrics', 'slug': 'http://www.metrolyrics.com/02-lyrics-nirvana.html', 'year': '2017', 'popularity': 'width:6%;'}, {'title': 'About A Girl Lyrics', 'slug': 'http://www.metrolyrics.com/about-a-girl-lyrics-nirvana.html', 'year': '1991', 'popularity': 'width:78.283044535628%;'}, {'title': 'Aero Zeppelin Lyrics', 'slug': 'http://www.metrolyrics.com/aero-zeppelin-lyrics-nirvana.html', 'year': '2006', 'popularity': 'width:6%;'}, {'title': "Ain't It A Shame Lyrics", 'slug': 'http://www.metrolyrics.com/aint-it-a-shame-lyrics-nirvana.html', 'year': '2007', 'popularity': 'width:16.945767347523%;'}, {'title': 'Alcohol / High On The Hog Lyrics', 'slug': 'http://www.metrolyrics.com/alcohol-high-on-the-hog-lyrics-nirvana.html', 'year': '2006', 'popularity': 'width:6%;'}, {'title': 'All Apologies Lyrics', 'slug': 'http://www.metrolyrics.com/all-apologies-lyrics-nirvana.html', 'year': '1991', 'popularity': 'width:78.186337622204%;'}, {'title': 'Aneurism Lyrics', 'slug': 'http://www.metrolyrics.com/aneurism-lyrics-nirvana.html', 'year': '2006', 'popularity': 'width:6%;'}, {'title': 'Aneurysm Lyrics', 'slug': 'http://www.metrolyrics.com/aneurysm-lyrics-nirvana.html', 'year': '2009', 'popularity': 'width:50.255168723824%;'}, {'title': 'Aneurysm [mark Goodier Session] Lyrics', 'slug': 'http://www.metrolyrics.com/aneurysm-mark-goodier-session-lyrics-nirvana.html', 'year': '2006', 'popularity': 'width:6%;'}, {'title': 'Anorexorcist Lyrics', 'slug': 'http://www.metrolyrics.com/anorexorcist-lyrics-nirvana.html', 'year': '2006', 'popularity': 'width:6%;'}, {'title': 'Asshole Lyrics', 'slug': 'http://www.metrolyrics.com/asshole-lyrics-nirvana.html', 'year': '2007', 'popularity': 'width:10.691588816652%;'}, {'title': "Baba O' Riley Lyrics", 'slug': 'http://www.metrolyrics.com/baba-o-riley-lyrics-nirvana.html', 'year': '2006', 'popularity': 'width:6%;'}, {'title': 'Bad Moon Rising Lyrics', 'slug': 'http://www.metrolyrics.com/bad-moon-rising-lyrics-nirvana.html', 'year': '2006', 'popularity': 'width:6%;'}, {'title': 'Bambi Slaughter / Bambi Kill Lyrics', 'slug': 'http://www.metrolyrics.com/bambi-slaughter-bambi-kill-lyrics-nirvana.html', 'year': '2006', 'popularity': 'width:6%;'}, {'title': 'Beans Lyrics', 'slug': 'http://www.metrolyrics.com/beans-lyrics-nirvana.html', 'year': '2006', 'popularity': 'width:6%;'}, {'title': 'Been A Son Lyrics', 'slug': 'http://www.metrolyrics.com/been-a-son-lyrics-nirvana.html', 'year': '2009', 'popularity': 'width:21.383177633304%;'}, {'title': 'Been A Son [mark Goodier Session] Lyrics', 'slug': 'http://www.metrolyrics.com/been-a-son-mark-goodier-session-lyrics-nirvana.html', 'year': '2006', 'popularity': 'width:6%;'}, {'title': 'Been And Son Lyrics', 'slug': 'http://www.metrolyrics.com/been-and-son-lyrics-nirvana.html', 'year': '2006', 'popularity': 'width:6%;'}, {'title': 'Beeswax Lyrics', 'slug': 'http://www.metrolyrics.com/beeswax-lyrics-nirvana.html', 'year': '2006', 'popularity': 'width:6%;'}, {'title': 'Big Cheese Lyrics', 'slug': 'http://www.metrolyrics.com/big-cheese-lyrics-nirvana.html', 'year': '2009', 'popularity': 'width:21.383177633304%;'}, {'title': 'Big Long Now Lyrics', 'slug': 'http://www.metrolyrics.com/big-long-now-lyrics-nirvana.html', 'year': '2006', 'popularity': 'width:6%;'}, {'title': 'Blandest Lyrics', 'slug': 'http://www.metrolyrics.com/blandest-lyrics-nirvana.html', 'year': '2006', 'popularity': 'width:6%;'}, {'title': 'Blew Lyrics', 'slug': 'http://www.metrolyrics.com/blew-lyrics-nirvana.html', 'year': '2009', 'popularity': 'width:32.074766449956%;'}, {'title': 'Born In A Junkyard Lyrics', 'slug': 'http://www.metrolyrics.com/born-in-a-junkyard-lyrics-nirvana.html', 'year': '2006', 'popularity': 'width:10.691588816652%;'}, {'title': 'Breed Lyrics', 'slug': 'http://www.metrolyrics.com/bre ...

# %%
df = pd.DataFrame(rows, columns=['title', 'year', 'popularity', 'slug'])
df.head()
# Out:
#                                             title  year  \
# 0  (new Wave) Polly [mark Goodier Session] Lyrics  2006
# 1                                       02 Lyrics  2017
# 2                             About A Girl Lyrics  1991
# 3                            Aero Zeppelin Lyrics  2006
# 4                         Ain't It A Shame Lyrics  2007
#
#                 popularity                                               slug
# 0                width:6%;  http://www.metrolyrics.com/new-wave-polly-mark...
# 1                width:6%;  http://www.metrolyrics.com/02-lyrics-nirvana.html
# 2  width:78.283044535628%;  http://www.metrolyrics.com/about-a-girl-lyrics...
# 3                width:6%;  http://www.metrolyrics.com/aero-zeppelin-lyric...
# 4  width:16.945767347523%;  http://www.metrolyrics.com/aint-it-a-shame-lyr...

# %%
df.title = df.title.str.extract("(.*)\sLyrics")
df.year = df.year.astype(int)

## Bonus
df.popularity = df.popularity.str.extract(":(.*)%").astype(float)

df.slug = df.slug.str.extract(".com(.*)")

# %%
df.head()
# Out:
#                                      title  year  popularity  \
# 0  (new Wave) Polly [mark Goodier Session]  2006    6.000000
# 1                                       02  2017    6.000000
# 2                             About A Girl  1991   78.283045
# 3                            Aero Zeppelin  2006    6.000000
# 4                         Ain't It A Shame  2007   16.945767
#
#                                                 slug
# 0  /new-wave-polly-mark-goodier-session-lyrics-ni...
# 1                            /02-lyrics-nirvana.html
# 2                  /about-a-girl-lyrics-nirvana.html
# 3                 /aero-zeppelin-lyrics-nirvana.html
# 4               /aint-it-a-shame-lyrics-nirvana.html

# %%
df.to_csv("slugs.csv", index=False)

# %%
df = pd.read_csv("slugs.csv")
df.head()
# Out:
#                                      title  year  popularity  \
# 0  (new Wave) Polly [mark Goodier Session]  2006    6.000000
# 1                                       02  2017    6.000000
# 2                             About A Girl  1991   78.283045
# 3                            Aero Zeppelin  2006    6.000000
# 4                         Ain't It A Shame  2007   16.945767
#
#                                                 slug
# 0  /new-wave-polly-mark-goodier-session-lyrics-ni...
# 1                            /02-lyrics-nirvana.html
# 2                  /about-a-girl-lyrics-nirvana.html
# 3                 /aero-zeppelin-lyrics-nirvana.html
# 4               /aint-it-a-shame-lyrics-nirvana.html

# %%
rows = []

def scrape_page(row):
    url = "http://www.metrolyrics.com" + row['slug']
    
    response = requests.get(url)
    doc = BeautifulSoup(response.text)
    
    page = {}

    try:
        for lyrics in doc.find(id="lyrics-body-text").find_all(class_="verse"):
            page['lyrics'] = lyrics.text.strip()
    except: pass
    
    rows.append(page)

    return pd.Series(page)

# %%
lyrics_df = df.apply(scrape_page, axis=1)

# %%
all_df = df.merge(lyrics_df, left_index=True, right_index=True)
all_df.head(10)
# Out:
#                                      title  year  popularity  \
# 0  (new Wave) Polly [mark Goodier Session]  2006    6.000000
# 1                                       02  2017    6.000000
# 2                             About A Girl  1991   78.283045
# 3                            Aero Zeppelin  2006    6.000000
# 4                         Ain't It A Shame  2007   16.945767
# 5                Alcohol / High On The Hog  2006    6.000000
# 6                            All Apologies  1991   78.186338
# 7                                 Aneurism  2006    6.000000
# 8                                 Aneurysm  2009   50.255169
# 9          Aneurysm [mark Goodier Session]  2006    6.000000
#
#                                                 slug  \
# 0  /new-wave-polly-mark-goodier-session-lyrics-ni...
# 1                            /02-lyrics-nirvana.html
# 2                  /about-a-girl-lyrics-nirvana.html
# 3                 /aero-zeppelin-lyrics-nirvana.html
# 4               /aint-it-a-shame-lyrics-nirvana.html
# 5       /alcohol-high-on-the-hog-lyrics-nirvana.html
# 6                 /all-apologies-lyrics-nirvana.html
# 7                      /aneurism-lyrics-nirvana.html
# 8                      /aneurysm-lyrics-nirvana.html
# 9  /aneurysm-mark-goodier-session-lyrics-nirvana....
#
#                                               lyrics
# 0  Polly says her back hurts\nAnd she's just as b...
# 1                                                NaN
# 2  I need an easy friend\nI do with an ear to len...
# 3  Hey ...\nHey ...\nHey ...\nHey ...\nHey ...\nH...
# 4  Ain't it a shame to go fishin on a Sunday\nAin...
# 5  My baby taught me how to choke\nMy baby taught...
# 6  All in all is all we are\nAll in all is all we...
# 7  She keeps it pumpin' straight to my heart\nShe...
# 8  She keeps it pumpin' straight to my heart\nShe...
# 9  She keeps it pumpin' straight to my heart\nShe...

# %%
all_df.lyrics = all_df.lyrics.str.split('\n')
all_df.head()
# Out:
#                                      title  year  popularity  \
# 0  (new Wave) Polly [mark Goodier Session]  2006    6.000000
# 1                                       02  2017    6.000000
# 2                             About A Girl  1991   78.283045
# 3                            Aero Zeppelin  2006    6.000000
# 4                         Ain't It A Shame  2007   16.945767
#
#                                                 slug  \
# 0  /new-wave-polly-mark-goodier-session-lyrics-ni...
# 1                            /02-lyrics-nirvana.html
# 2                  /about-a-girl-lyrics-nirvana.html
# 3                 /aero-zeppelin-lyrics-nirvana.html
# 4               /aint-it-a-shame-lyrics-nirvana.html
#
#                                               lyrics
# 0  [Polly says her back hurts, And she's just as ...
# 1                                                NaN
# 2  [I need an easy friend, I do with an ear to le...
# 3  [Hey ..., Hey ..., Hey ..., Hey ..., Hey ..., ...
# 4  [Ain't it a shame to go fishin on a Sunday, Ai...

# %%
all_df.to_csv('metrolyrics.csv', index=False)
